# %% [markdown]
# #### Sequential Method

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model1 = Sequential()
# Add the first (input) layer (10 nodes) with input shape 13 element vector (1D).
model1.add(Dense(10, input_shape=(13,)))
# Add the second (hidden) layer of 10 nodes.
model1.add(Dense(10))
# Add the third (output) layer of 1 node.
model1.add(Dense(1))
# Out:
# 2022-12-01 14:06:43.627893: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-01 14:06:53.167835: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
model2 = Sequential([Dense(10, input_shape=(13,)),
                   # Add the second (hidden) layer of 10 nodes.
                   Dense(10),
                   # Add the third (output) layer of 1 node.
                   Dense(1)
                   ])

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                140
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Functional API Method

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense
 
inputs = Input((13,))
input = Dense(10)(inputs) # first layer 
hidden = Dense(10)(input)
hidden2 = Dense(8)(hidden)
output = Dense(1)(hidden)
model3 = Model(inputs, output)

# %%
model3.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 13)]              0
#
#  dense_6 (Dense)             (None, 10)                140
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________
