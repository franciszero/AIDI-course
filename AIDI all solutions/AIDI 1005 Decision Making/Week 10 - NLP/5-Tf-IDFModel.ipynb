# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

X_train.head()
X_train.values
# Out:
# array([["['wake', 'ltgt', 'morning']"],
#        ["['cant', 'u', 'try', 'new', 'invention', 'flyim', 'joking']"],
#        ["['hi', 'hope', 'u', 'get', 'txtjourney', 'hasnt', 'gdnow', '50', 'mins', 'late', 'think']"],
#        ...,
#        ["['great', 'comedycant', 'stop', 'laughing', 'da']"],
#        ["['pick', 'drop', 'carso', 'problem']"],
#        ["['say', 'slowly', 'godi', 'love', 'amp', 'need', 'youclean', 'heart', 'bloodsend', 'ten', 'special', 'people', 'amp', 'u', 'c', 'miracle', 'tomorrow', 'itplspls']"]],
#       dtype=object)

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
type(X_train['clean_text'][0])
# Out:
# str

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'wake': 7766,
#  'ltgt': 4505,
#  'morning': 4866,
#  'cant': 1718,
#  'try': 7462,
#  'new': 5030,
#  'invention': 3920,
#  'flyim': 3049,
#  'joking': 4054,
#  'hi': 3582,
#  'hope': 3662,
#  'get': 3254,
#  'txtjourney': 7504,
#  'hasnt': 3499,
#  'gdnow': 3231,
#  '50': 577,
#  'mins': 4767,
#  'late': 4263,
#  'think': 7240,
#  'thats': 7204,
#  'good': 3328,
#  'need': 5003,
#  'drugs': 2592,
#  'congratulations': 2064,
#  'thanks': 7193,
#  'friend': 3143,
#  '2000': 370,
#  'xmas': 8125,
#  'prize': 5743,
#  'claim': 1914,
#  'easy': 2638,
#  'call': 1674,
#  '08718726978': 130,
#  '10p': 258,
#  'per': 5458,
#  'minute': 4773,
#  'btnationalrate': 1602,
#  'job': 4037,
#  'like': 4354,
#  'entrepreneurs': 2745,
#  'uhhhhrmm': 7522,
#  'isnt': 3952,
#  'tb': 7109,
#  'test': 7169,
#  'bad': 1250,
#  'youre': 8213,
#  'sick': 6477,
#  'ill': 3799,
#  'evening': 2789,
#  'ideas': 3781,
#  'aiyo': 944,
#  'always': 987,
#  'ex': 2816,
#  'one': 5244,
#  'dunno': 2614,
#  'abt': 813,
#  'mei': 4690,
#  'reply': 6044,
#  'first': 3008,
#  'time': 7297,
#  'fast': 2911,
#  'lucky': 4512,
#  'workin': 8018,
#  'huh': 3727,
#  'got': 3348,
#  'bao': 1275,
#  'ur': 7608,
#  'sugardad': 6958,
#  'ahgee': 927,
#  'housemaid': 3687,
#  'murderer': 4931,
#  'coz': 2142,
#  'man': 4590,
#  'murdered': 4930,
#  'th': 7188,
#  'january': 4002,
#  'public': 5812,
#  'holiday': 3635,
#  'govtinstituitions': 3355,
#  'closedincluding': 1942,
#  'post': 5649,
#  'officeunderstand': 5208,
#  'take': 7069,
#  'us': 7621,
#  'shopping': 6440,
#  'mark': 4615,
#  'distract': 2482,
#  'isaiahd': 3946,
#  'sun': 6973,
#  'come': 1999,
#  'earth': 2631,
#  'send': 6334,
#  'luv': 4525,
#  'rays': 5908,
#  'cloud': 1948,
#  'river': 6131,
#  'rain': 5879,
#  'meet': 4682,
#  'care': 1733,
#  'msg': 4892,
#  'gud': 3417,
#  'evng': 2808,
#  'records': 5966,
#  'indicate': 3851,
#  'maybe': 4659,
#  'entitled': 2744,
#  '5000': 579,
#  'pounds': 5663,
#  'compensation': 2021,
#  'accident': 825,
#  'free': 3118,
#  'stop': 6858,
#  'txt': 7499,
#  'resume': 6091,
#  'really': 5934,
#  'gooddhanush': 3329,
#  'rocks': 6139,
#  'sms': 6600,
#  'ac': 817,
#  'sptv': 6768,
#  'jersey': 4024,
#  'devils': 2404,
#  'detroit': 2398,
#  'red': 5971,
#  'wings': 7947,
#  'play': 5557,
#  'ice': 3771,
#  'hockey': 3625,
#  'correct': 2108,
#  'incorrect': 3839,
#  'end': 2714,
#  'steyn': 6839,
#  'surely': 7000,
#  'wicket': 7920,
#  'yeah': 8158,
#  'apologetic': 1066,
#  'fallen': 2890,
#  'actin': 848,
#  'spoilt': 6747,
#  'child': 1873,
#  'caught': 1770,
#  'till': 7295,
#  'wont': 8001,
#  'go': 3297,
#  'badly': 1252,
#  'cheers': 1846,
#  'lou': 4468,
#  'goodnite': 3337,
#  'shame': 6393,
#  'neva': 5027,
#  'came': 1703,
#  'ya': 8142,
#  'gailxx': 3193,
#  'local': 4413,
#  'dates': 2279,
#  'area': 1101,
#  'lots': 4463,
#  'people': 5456,
#  'registered': 5994,
#  'date': 2277,
#  'start': 6806,
#  '18': 333,
#  'wwwflirtpartyus': 8086,
#  'replys150': 6047,
#  'oh': 5217,
#  'den': 2361,
#  'muz': 4941,
#  'change': 1804,
#  'plan': 5547,
#  'liao': 4331,
#  'back': 1246,
#  'yan': 8149,
#  'jiu': 4033,
#  'havent': 3507,
#  'lei': 4313,
#  'next': 5039,
#  'mon': 4839,
#  'someone': 6638,
#  'know': 4188,
#  'asked': 1148,
#  'dating': 2280,
#  'service': 6356,
#  'contact': 2076,
#  'guess': 3422,
#  '09058091854': 164,
#  'revealed': 6100,
#  'po': 5583,
#  'box385': 1520,
#  'm6': 4544,
#  '6wu': 652,
#  'edison': 2651,
#  'rightly': 6116,
#  'said': 6206,
#  'fool': 3069,
#  'ask': 1146,
#  'questions': 5855,
#  'wise': 7958,
#  'answer': 1035,
#  'speechless': 6720,
#  'viva': 7717,
#  'gm': 3292,
#  'yeshere': 8178,
#  'tv': 7488,
#  'available': 1202,
#  'work': 8015,
#  'place': 5541,
#  'hey': 3578,
#  'told': 7349,
#  'name': 4962,
#  'gautham': 3217,
#  'ah': 924,
#  'mobile': 4816,
#  'added': 861,
#  'list': 4385,
#  'wwwfullonsmscom': 8087,
#  'great': 3382,
#  'visit': 7711,
#  'fullonsmscom': 3176,
#  'frnd': 3152,
#  'best': 1376,
#  'way': 7822,
#  'avoid': 1213,
#  'missunderstding': 4788,
#  'wit': 7965,
#  'beloved': 1367,
#  'ones': 5246,
#  'fancy': 2901,
#  'meetin': 4684,
#  'cha': 1793,
#  'åð': 8247,
#  'hav': 3505,
#  'lil': 4360,
#  'beverage': 1386,
#  'ring': 6119,
#  'l8r': 4219,
#  'quite': 5861,
#  'tired': 7307,
#  'vpist': 7734,
#  'love': 4474,
#  'pete': 5486,
#  'nah': 4956,
#  'im': 3801,
#  'goin': 3314,
#  'wrks': 8057,
#  'wot': 8038,
#  'bout': 1509,
#  'started': 6807,
#  'dont': 2533,
#  'pray': 5687,
#  'anything': 1052,
#  'see': 6307,
#  'help': 3550,
#  'guys': 3436,
#  'forward': 3099,
#  'link': 4375,
#  'babe': 1237,
#  'doin': 2521,
#  '2nite': 441,
#  'annie': 1025,
#  'lol': 4431,
#  'ok': 5223,
#  'snatch': 6611,
#  'purse': 5830,
#  'thk': 7249,
#  'shld': 6431,
#  'wana': 7785,
#  'lessons': 4324,
#  'haha': 3448,
#  'whole': 7914,
#  'stretch': 6883,
#  'takes': 7072,
#  'part': 5403,
#  'wrc': 8047,
#  'rally': 5888,
#  'oz': 5354,
#  'lucozade': 4513,
#  'energy': 2722,
#  'text': 7174,
#  'le': 4289,
#  '61200': 616,
#  '25p': 400,
#  'packs': 5360,
#  'lucozadecoukwrc': 4514,
#  'itcould': 3958,
#  'something': 6644,
#  'want': 7788,
#  'explicit': 2851,
#  'sex': 6369,
#  '30': 461,
#  'secs': 6302,
#  '02073162414': 9,
#  'costs': 2116,
#  '20pmin': 381,
#  'gsex': 3411,
#  'pobox': 5584,
#  '2667': 404,
#  'wc1n': 7826,
#  '3xx': 516,
#  'random': 5891,
#  'dude': 2606,
#  'info': 3860,
#  'sheets': 6405,
#  'party': 5411,
#  'never': 5028,
#  'study': 6906,
#  'safe': 6202,
#  'wamma': 7782,
#  'laidwant': 4237,
#  'real': 5926,
#  'doggin': 2516,
#  'locations': 4415,
#  'sent': 6343,
#  'direct': 2456,
#  'join': 4045,
#  'uks': 7527,
#  'largest': 4258,
#  'dogging': 2517,
#  'network': 5024,
#  'dogs': 2519,
#  '69696': 631,
#  'nownyt': 5141,
#  'ec2a': 2644,
#  '3lp': 502,
#  '150msg': 296,
#  'major': 4581,
#  'roles': 6145,
#  'community': 2015,
#  'outreach': 5327,
#  'rock': 6138,
#  'mel': 4693,
#  'services': 6357,
#  'inclusive': 3834,
#  'credits': 2168,
#  'pls': 5573,
#  'goto': 3350,
#  'wwwcomuknet': 8084,
#  'login': 4424,
#  '3qxj9': 507,
#  'unsubscribe': 7583,
#  'extra': 2857,
#  'charge': 1813,
#  '08702840625comuk': 71,
#  '220cm2': 389,
#  '9ae': 781,
#  'aunts': 1194,
#  'anniversary': 1026,
#  'tarpon': 7093,
#  'springs': 6765,
#  'right': 6114,
#  'though': 7259,
#  'give': 3281,
#  'space': 6697,
#  'starting': 6810,
#  'become': 1333,
#  'issue': 3954,
#  'going': 3315,
#  'suggest': 6959,
#  'setting': 6361,
#  'definite': 2341,
#  'move': 4880,
#  'outif': 5324,
#  'still': 6846,
#  'greece': 3388,
#  'ready': 5924,
#  'meim': 4691,
#  'office': 5206,
#  'reverse': 6101,
#  'cheating': 1835,
#  'mathematics': 4641,
#  'lul': 4518,
#  'gettin': 3260,
#  'juicy': 4073,
#  'gossip': 3346,
#  'hospital': 3673,
#  'two': 7498,
#  'nurses': 5161,
#  'talking': 7080,
#  'fat': 2915,
#  'thinks': 7244,
#  'shes': 6410,
#  'obese': 5184,
#  'oyea': 5352,
#  'nothis': 5125,
#  'kallis': 4099,
#  'home': 3641,
#  'groundamla': 3403,
#  'town': 7406,
#  'durban': 2616,
#  'baby': 1241,
#  'cos': 2112,
#  'wait': 7759,
#  'lar': 4255,
#  'tot': 7396,
#  'finish': 2995,
#  'lab': 4224,
#  'wat': 7807,
#  'gave': 3218,
#  'photo': 5507,
#  'driving': 2582,
#  'tmr': 7327,
#  'wanna': 7786,
#  'yck': 8156,
#  'stupidits': 6917,
#  'possible': 5646,
#  'might': 4745,
#  'sch': 6265,
#  'yar': 8150,
#  'salon': 6215,
#  'boring': 1496,
#  'hun': 3731,
#  'comin': 2007,
#  '2nitetell': 442,
#  'every1': 2795,
#  'sorry': 6672,
#  'ava': 1200,
#  'goodtimeoli': 3341,
#  'rang': 5895,
#  'melnite': 4696,
#  'ifink': 3790,
#  'mite': 4795,
#  'sortedbut': 6678,
#  'il': 3797,
#  'explain': 2850,
#  'everythin': 2802,
#  'monl8rsx': 4848,
#  'prepare': 5701,
#  'pounded': 5662,
#  'every': 2794,
#  'night': 5052,
#  'thts': 7278,
#  'gods': 3308,
#  'gift': 3266,
#  'birds': 1414,
#  'humans': 3730,
#  'natural': 4983,
#  'frm': 3151,
#  'god': 3305,
#  'found': 3102,
#  'diff': 2431,
#  'farm': 2907,
#  'shop': 6438,
#  'buy': 1644,
#  'cheese': 1848,
#  'hmv': 3622,
#  'bonus': 1483,
#  'special': 6711,
#  '500': 578,
#  'genuine': 3248,
#  'vouchers': 7732,
#  '86688': 737,
#  'infowww100percentrealcom': 3868,
#  'amp': 1002,
#  'drive': 2579,
#  'coherently': 1971,
#  'twenty': 7492,
#  'awake': 1218,
#  'loving': 4486,
#  'kiss': 4166,
#  'alright': 978,
#  'well': 7868,
#  'bring': 1569,
#  'lobby': 4412,
#  'argh': 1105,
#  '3g': 498,
#  'spotty': 6760,
#  'anyway': 1056,
#  'thing': 7237,
#  'remember': 6013,
#  'research': 6058,
#  'province': 5799,
#  'sterling': 6834,
#  'problemfree': 5753,
#  'places': 5545,
#  'looked': 4443,
#  'booked': 1486,
#  'ticket': 7285,
#  'pongal': 5617,
#  'meant': 4671,
#  'say': 6252,
#  'getting': 3261,
#  'bored': 1494,
#  'bridgwater': 1563,
#  'banter': 1274,
#  'happened': 3483,
#  'cruise': 2185,
#  'perform': 5463,
#  'write': 8052,
#  'paper': 5379,
#  'movie': 4882,
#  'midnight': 4743,
#  'sir': 6512,
#  'waiting': 7763,
#  'mail': 4575,
#  'din': 2446,
#  'nope': 5109,
#  'wif': 7924,
#  'sis': 6517,
#  'lor': 4452,
#  'aft': 902,
#  'bathing': 1297,
#  'dog': 2513,
#  'bathe': 1296,
#  'looks': 4446,
#  'soon': 6661,
#  'watching': 7812,
#  'surya': 7011,
#  'pm': 5581,
#  'vijay': 7694,
#  'pokkiri': 5607,
#  'asking': 1150,
#  'slippers': 6567,
#  'gone': 3323,
#  'last': 4260,
#  'year': 8160,
#  'pa': 5355,
#  'gas': 3213,
#  'station': 6818,
#  'sexy': 6373,
#  'today': 7336,
#  'find': 2986,
#  'even': 2788,
#  'flirt': 3034,
#  'age': 912,
#  'eg': 2665,
#  'sam': 6217,
#  '25': 397,
#  'recdthirtyeight': 5947,
#  'pence': 5451,
#  'sry': 6780,
#  'dajst': 2252,
#  'nw': 5169,
#  'chance': 1802,
#  'search': 6292,
#  'hard': 3491,
#  'itlet': 3964,
#  'dear': 2310,
#  'please': 5566,
#  '447801259231': 538,
#  'secret': 6299,
#  'admirer': 873,
#  'looking': 4445,
#  'make': 4582,
#  'ufind': 7517,
#  'rreveal': 6170,
#  'specialcall': 6712,
#  '09058094597': 170,
#  'tell': 7142,
#  'long': 4438,
#  'film': 2977,
#  'yet': 8184,
#  'dats': 2283,
#  'things': 7239,
#  'bigger': 1399,
#  'little': 4396,
#  'pocy': 5600,
#  'bell': 1362,
#  'coming': 2008,
#  'dinner': 2451,
#  'dump': 2612,
#  'heap': 3521,
#  'mom': 4835,
#  'decided': 2324,
#  'lowes': 4492,
#  'opinion': 5273,
#  'jada': 3993,
#  'kusruthi': 4212,
#  'lovable': 4473,
#  'silent': 6491,
#  'spl': 6740,
#  'character': 1811,
#  'matured': 4650,
#  'stylish': 6921,
#  'simple': 6496,
#  'worry': 8030,
#  'finished': 2997,
#  'march': 4611,
#  'ish': 3949,
#  'match': 4634,
#  'startedindia': 6808,
#  'born': 1497,
#  'another': 1032,
#  'idiot': 3784,
#  'hello': 3546,
#  'ru': 6177,
#  'guy': 3435,
#  'met': 4734,
#  'walkabout': 7771,
#  'far': 2906,
#  'hows': 3696,
#  'everyone': 2799,
#  'else': 2693,
#  'messagethanks': 4731,
#  'using': 7632,
#  'auction': 1185,
#  'subscription': 6935,
#  '150pmsgrcvd': 307,
#  'skip': 6541,
#  'customercare': 2223,
#  '08718726270': 126,
#  'sure': 6999,
#  'mean': 4667,
#  'much': 4909,
#  'hm': 3610,
#  'friday': 3138,
#  'hell': 3544,
#  'gonna': 3326,
#  'weeks': 7856,
#  'slob': 6571,
#  'already': 977,
#  'done': 2531,
#  'dis': 2463,
#  'pierre': 5525,
#  'cardin': 1731,
#  'normal': 5114,
#  '20': 368,
#  'sale': 6212,
#  'pizza': 5539,
#  'youve': 8219,
#  'car': 1728,
#  'house': 3686,
#  'parentsi': 5394,
#  'hand': 3467,
#  'princess': 5732,
#  'food': 3068,
#  'fridge': 3141,
#  'meal': 4665,
#  'tonight': 7371,
#  'oops': 5264,
#  'shower': 6460,
#  'called': 1688,
#  'parking': 5402,
#  'garage': 3208,
#  'collapsed': 1981,
#  'university': 7569,
#  'crazy': 2159,
#  'stuff': 6909,
#  'happen': 3481,
#  'toldshe': 7350,
#  'wats': 7820,
#  'matter': 4646,
#  'customer': 2222,
#  'tc': 7111,
#  'wwwtcbiz': 8107,
#  '150pmin': 304,
#  'polo': 5610,
#  'ltd': 4501,
#  'suite': 6962,
#  '373': 488,
#  'london': 4435,
#  'w1j': 7744,
#  '6hl': 642,
#  'busy': 1638,
#  'taught': 7100,
#  'ranjith': 5897,
#  'becaus': 1331,
#  'hes': 3573,
#  'verifying': 7676,
#  'project': 5773,
#  'prabu': 5677,
#  'mistake': 4791,
#  'slave': 6550,
#  'pictures': 5520,
#  'bright': 1564,
#  'light': 4350,
#  'cell': 1786,
#  'phone': 5502,
#  'ran': 5890,
#  'younger': 8211,
#  'pretty': 5718,
#  'babies': 1240,
#  'together': 7343,
#  'ìï': 8253,
#  'attending': 1179,
#  'da': 2238,
#  'talks': 7081,
#  'tomarrow': 7354,
#  'final': 2982,
#  'hearing': 3525,
#  'laptop': 4254,
#  'case': 1756,
#  'afternoon': 904,
#  'sunshine': 6980,
#  'dawns': 2288,
#  'day': 2289,
#  'refreshed': 5985,
#  'happy': 3490,
#  'alive': 964,
#  'breathe': 1555,
#  'air': 937,
#  'smile': 6588,
#  'whats': 7893,
#  'sleeping': 6553,
#  'suntec': 6981,
#  'yo': 8193,
#  'could': 2124,
#  'pick': 5513,
#  'working': 8019,
#  'eyes': 2863,
#  'philosophy': 5499,
#  'later': 4268,
#  'bit': 1419,
#  'chat': 1826,
#  'east': 2635,
#  'coast': 1960,
#  'raining': 5880,
#  'mah': 4573,
#  'leave': 4300,
#  'orchard': 5291,
#  'armand': 1114,
#  'says': 6256,
#  'ass': 1153,
#  'epsilon': 2753,
#  'valentines': 7650,
#  'early': 2629,
#  'hundreds': 3733,
#  'handsomes': 3474,
#  'beauties': 1326,
#  'wish': 7959,
#  'thought': 7260,
#  'aunties': 1193,
#  'uncles': 7541,
#  '1st': 357,
#  'quiteamuzing': 5862,
#  'thatåõscool': 7206,
#  'ive': 3978,
#  'reached': 5917,
#  'finally': 2984,
#  'haf': 3447,
#  'keep': 4122,
#  'card': 1729,
#  'fine': 2989,
#  'week': 7851,
#  'dull': 2610,
#  'fun': 3178,
#  'ssindia': 6782,
#  'draw': 2562,
#  'series': 6352,
#  'many': 4606,
#  'years': 8161,
#  'south': 6692,
#  'african': 901,
#  'soil': 6627,
#  'jess': 4025,
#  'eve': 2785,
#  'xxx': 8132,
#  'burger': 1624,
#  'pain': 5366,
#  'killing': 4154,
#  'cooking': 2099,
#  'saw': 6251,
#  'ron': 6150,
#  'burgundy': 1625,
#  'captaining': 1727,
#  'boat': 1471,
#  'smth': 6606,
#  'message': 4722,
#  'stil': 6845,
#  'fucked': 3166,
#  'nite': 5069,
#  'went': 7876,
#  'tobed': 7333,
#  '430': 533,
#  '630': 622,
#  'knw': 4196,
#  'nt': 5149,
#  'may': 4657,
#  'frnds': 3153,
#  'classmates': 1923,
#  'believe': 1360,
#  'lie': 4340,
#  'twice': 7493,
#  'saying': 6255,
#  'okie': 5229,
#  'camera': 1704,
#  'awarded': 1220,
#  'sipix': 6510,
#  'digital': 2441,
#  '09061221066': 180,
#  'fromm': 3159,
#  'landline': 4242,
#  'delivery': 2356,
#  'within': 7966,
#  '28': 407,
#  'days': 2292,
#  'messages': 4728,
#  'put': 5834,
#  'lightly': 4352,
#  'custom': 2221,
#  'checkboxes': 1838,
#  'hardcore': 3492,
#  'wondering': 7999,
#  'smiling': 6592,
#  'coping': 2103,
#  'distance': 2481,
#  'jus': 4082,
#  'avatar': 1205,
#  'nigro': 5060,
#  'email': 2697,
#  'id': 3776,
#  'old': 5236,
#  'commercial': 2012,
#  'ard': 1099,
#  'dat': 2275,
#  'nice': 5045,
#  'shirts': 6423,
#  'wear': 7832,
#  'nudist': 5153,
#  'themed': 7213,
#  'mu': 4908,
#  'beautiful': 1327,
#  'girl': 3274,
#  'ever': 2793,
#  'seen': 6315,
#  'common': 2014,
#  'room': 6151,
#  'content': 2080,
#  'order': 5292,
#  'resent': 6060,
#  'previous': 5721,
#  'attempt': 1176,
#  'failed': 2877,
#  'due': 2609,
#  'error': 2760,
#  'queries': 5851,
#  'customersqueriesnetvisionukcom': 2225,
#  'bruce': 1592,
#  'fowler': 3105,
#  'moms': 4838,
#  'park': 5398,
#  'story': 6872,
#  'running': 6189,
#  'managed': 4593,
#  'minutes': 4774,
#  'needed': 5005,
#  'oxygen': 5351,
#  'resort': 6070,
#  'roller': 6147,
#  'option': 5283,
#  'msn': 4902,
#  'yijuehotmailcom': 8190,
#  'set': 6360,
#  'joys': 4066,
#  'father': 2917,
#  'john': 4043,
#  'ans': 1033,
#  'ths': 7276,
#  'iq': 3938,
#  'tis': 7312,
#  'ias': 3761,
#  'question': 5853,
#  'also': 982,
#  'didnt': 2423,
#  'na': 4951,
#  'rajini': 5885,
#  'comes': 2003,
#  'chief': 1864,
#  'talk': 7076,
#  'royal': 6166,
#  'june': 4078,
#  'idk': 3785,
#  'since': 6500,
#  'moved': 4881,
#  'butting': 1642,
#  'heads': 3517,
#  'freedom': 3120,
#  'vs': 7737,
#  'responsibility': 6078,
#  'shit': 6424,
#  'deal': 2304,
#  'barely': 1279,
#  'keeping': 4123,
#  'gets': 3258,
#  'themobhit': 7216,
#  'premium': 5699,
#  'pink': 5531,
#  'panther': 5374,
#  'game': 3202,
#  'sugababes': 6955,
#  'zebra': 8237,
#  'animation': 1021,
#  'badass': 1251,
#  'hoody': 3657,
#  'wallpaperall': 7778,
#  'around': 1120,
#  'hillsborough': 3591,
#  'impressively': 3821,
#  'sensible': 6342,
#  'feel': 2938,
#  'whens': 7901,
#  'jack': 3988,
#  'sayask': 6253,
#  'helpful': 3555,
#  'pretend': 5715,
#  'whatever': 7892,
#  'response': 6076,
#  'hypotheticalhuagauahahuagahyuhagga': 3759,
#  'needs': 5008,
#  'bed': 1337,
#  'fucking': 3168,
#  'dealing': 2307,
#  'netflix': 5021,
#  'hot': 3678,
#  'horny': 3670,
#  'willing': 7936,
#  'live': 4397,
#  'hear': 3522,
#  'strt': 6893,
#  '150p': 298,
#  'netcollex': 5020,
#  'ltdhelpdesk': 4503,
#  '02085076972': 10,
#  'entry': 2747,
#  'textpod': 7184,
#  'win': 7938,
#  '40gb': 524,
#  'ipod': 3937,
#  '250': 398,
#  'cash': 1757,
#  'wk': 7973,
#  'pod': 5601,
#  '84128': 723,
#  'tscs': 7468,
#  'wwwtextpodnet': 8109,
#  'custcare': 2219,
#  '08712405020': 95,
#  'parents': 5393,
#  'tonite': 7373,
#  'skype': 6545,
#  'accenture': 821,
#  'confirm': 2056,
#  'true': 7454,
#  'weekly': 7855,
#  'comp': 2016,
#  'word': 8010,
#  'enter': 2737,
#  'wwwtextcompcom': 8108,
#  'cust': 2218,
#  'ywhere': 8234,
#  'dogbreath': 2514,
#  'sounding': 6686,
#  'jan': 3998,
#  'thatåõs': 7205,
#  'al': 947,
#  'profile': 5768,
#  'seems': 6314,
#  'bpo': 1535,
#  'bold': 1477,
#  'bb': 1303,
#  'torch': 7389,
#  'life': 4342,
#  'means': 4670,
#  'lot': 4461,
#  'world': 8022,
#  'calls': 1697,
#  'friends': 3145,
#  'ge': 3233,
#  'snow': 6617,
#  'enjoy': 2730,
#  'tomorro': 7358,
#  'board': 1470,
#  'overheating': 5338,
#  'reslove': 6067,
#  'software': 6626,
#  'inst': 3890,
#  'pending': 5452,
#  '8o': 766,
#  'clock': 1937,
#  'rofl': 6142,
#  'betta': 1383,
#  'invest': 3921,
#  'anti': 1042,
#  'aging': 920,
#  'products': 5764,
#  'wan': 7783,
#  'lunch': 4519,
#  'canteen': 1720,
#  'number': 5156,
#  'knocking': 4187,
#  'door': 2538,
#  'gee': 3234,
#  'nvm': 5167,
#  'la': 4221,
#  'kaiez': 4093,
#  'dun': 2613,
#  'mind': 4757,
#  'jazz': 4010,
#  'oso': 5308,
#  'scared': 6262,
#  'hiphop': 3596,
#  'open': 5265,
#  'catch': 1767,
#  'taking': 7074,
#  'derek': 2379,
#  'taylor': 7106,
#  'walmart': 7780,
#  'mouse': 4878,
#  'desk': 2386,
#  'priscillas': 5739,
#  'double': 2546,
#  '12': 270,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8262 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.827 / Accuracy: 0.976
