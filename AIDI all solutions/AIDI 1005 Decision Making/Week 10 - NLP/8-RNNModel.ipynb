# %% [markdown]
# # Compare NLP Techniques: Build A Basic RNN

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import pandas as pd

X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

# %% [markdown]
# ### Prep Data

# %%
# Train the tokenizer and use that tokenizer to convert the sentences to sequences of numbers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train['clean_text'])
X_train_seq = tokenizer.texts_to_sequences(X_train['clean_text'])
X_test_seq = tokenizer.texts_to_sequences(X_test['clean_text'])

# %%
# Pad the sequences so each sequence is the same length
X_train_seq_padded = pad_sequences(X_train_seq, 50)
X_test_seq_padded = pad_sequences(X_test_seq, 50)

# %% [markdown]
# ### Build And Evaluate RNN

# %%
# Import the tools needed and use our previously defined functions to calculate precision and recall
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Construct our basic RNN model framework
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1, 32))
model.add(LSTM(32, dropout=0, recurrent_dropout=0))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          267360
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 276,769
# Trainable params: 276,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', precision_m, recall_m])

# %%
# Fit the RNN
history = model.fit(X_train_seq_padded, y_train['label'], 
                    batch_size=32, epochs=10,
                    validation_data=(X_test_seq_padded, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 7s 30ms/step - loss: 0.4547 - accuracy: 0.8385 - precision_m: 0.1263 - recall_m: 0.1175 - val_loss: 0.0933 - val_accuracy: 0.9722 - val_precision_m: 0.9895 - val_recall_m: 0.8165
# Epoch 2/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0446 - accuracy: 0.9868 - precision_m: 0.9892 - recall_m: 0.9235 - val_loss: 0.0494 - val_accuracy: 0.9874 - val_precision_m: 1.0000 - val_recall_m: 0.9066
# Epoch 3/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0132 - accuracy: 0.9966 - precision_m: 0.9962 - recall_m: 0.9729 - val_loss: 0.0653 - val_accuracy: 0.9848 - val_precision_m: 1.0000 - val_recall_m: 0.8921
# Epoch 4/10
# 140/140 [==============================] - 4s 26ms/step - loss: 0.0071 - accuracy: 0.9976 - precision_m: 0.9982 - recall_m: 0.9900 - val_loss: 0.0490 - val_accuracy: 0.9883 - val_precision_m: 0.9959 - val_recall_m: 0.9266
# Epoch 5/10
# 140/140 [==============================] - 4s 30ms/step - loss: 0.0010 - accuracy: 0.9999 - precision_m: 0.9999 - recall_m: 0.9989 - val_loss: 0.0583 - val_accuracy: 0.9892 - val_precision_m: 1.0000 - val_recall_m: 0.9266
# Epoch 6/10
# 140/140 [==============================] - 4s 27ms/step - loss: 4.0810e-04 - accuracy: 0.9999 - precision_m: 0.9688 - recall_m: 0.9681 - val_loss: 0.0663 - val_accuracy: 0.9857 - val_precision_m: 1.0000 - val_recall_m: 0.8883
# Epoch 7/10
# 140/140 [==============================] - 3s 25ms/step - loss: 2.5085e-04 - accuracy: 1.0000 - precision_m: 0.9858 - recall_m: 0.9858 - val_loss: 0.0706 - val_accuracy: 0.9857 - val_precision_m: 1.0000 - val_recall_m: 0.8883
# Epoch 8/10
# 140/140 [==============================] - 4s 27ms/step - loss: 1.1078e-04 - accuracy: 1.0000 - precision_m: 0.9849 - recall_m: 0.9849 - val_loss: 0.0679 - val_accuracy: 0.9865 - val_precision_m: 1.0000 - val_recall_m: 0.8940
# Epoch 9/10
# 140/140 [==============================] - 4s 30ms/step - loss: 9.5867e-05 - accuracy: 1.0000 - precision_m: 0.9948 - recall_m: 0.9948 - val_loss: 0.0748 - val_accuracy: 0.9865 - val_precision_m: 1.0000 - val_recall_m: 0.9026
# Epoch 10/10
# 140/140 [==============================] - 3s 24ms/step - loss: 9.2805e-05 - accuracy: 1.0000 - precision_m: 0.9968 - recall_m: 0.9968 - val_loss: 0.0755 - val_accuracy: 0.9865 - val_precision_m: 1.0000 - val_recall_m: 0.9026

# %%
# Plot basic evaluation metrics across epochs
import matplotlib.pyplot as plt
# %matplotlib inline

for i in ['accuracy', 'precision_m', 'recall_m']:
    acc = history.history[i]
    val_acc = history.history['val_{}'.format(i)]
    epochs = range(1, len(acc) + 1)

    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Results for {}'.format(i))
    plt.legend()
    plt.show()
