# %% [markdown]
# # word2vec: How To Implement word2vec

# %% [markdown]
# ### Explore Pre-trained Embeddings
#
# Some other options:
# - `glove-twitter-{25/50/100/200}`
# - `glove-wiki-gigaword-{50/200/300}`
# - `word2vec-google-news-300`
# - `word2vec-ruscorpora-news-300`

# %%
# Install gensim
# !pip install -U gensim
# Out:
# Requirement already up-to-date: gensim in c:\users\archi\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\users\archi\anaconda3\lib\site-packages (from gensim) (4.2.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\archi\anaconda3\lib\site-packages (from gensim) (1.2.1)
# Requirement already satisfied, skipping upgrade: Cython==0.29.14 in c:\users\archi\anaconda3\lib\site-packages (from gensim) (0.29.14)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in c:\users\archi\anaconda3\lib\site-packages (from gensim) (1.15.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\users\archi\anaconda3\lib\site-packages (from gensim) (1.19.5)
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\archi\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Load pretrained word vectors using gensim
import gensim.downloader as api

wiki_embeddings = api.load('glove-wiki-gigaword-100')

# %%
# Explore the word vector for "king"
wiki_embeddings['king']
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
# Find the words most similar to king based on the trained word vectors
wiki_embeddings.most_similar('king')
# Out:
# [('prince', 0.7682329416275024),
#  ('queen', 0.7507690191268921),
#  ('son', 0.7020887136459351),
#  ('brother', 0.6985775232315063),
#  ('monarch', 0.6977890729904175),
#  ('throne', 0.6919990181922913),
#  ('kingdom', 0.6811410188674927),
#  ('father', 0.6802029013633728),
#  ('emperor', 0.6712857484817505),
#  ('ii', 0.6676074266433716)]

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data and clean up column names
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though

# %%
# Clean data using the built in cleaner in gensim
messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                             text_clean
# 0  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1                                                                          [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3                                                       [dun, say, so, early, hor, already, then, say]
# 4                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   size=100,
                                   window=5,
                                   min_count=2)

# %%
# Explore the word vector for "king" base on our trained model
w2v_model.wv['king']
# Out:
# array([-0.01143144, -0.04015462,  0.04308384, -0.03775743, -0.06211508,
#        -0.05555646, -0.10239975,  0.02284142,  0.0696946 , -0.00443605,
#        -0.0740453 ,  0.03986885,  0.00818436,  0.11965823, -0.02451775,
#        -0.12746537,  0.09749493,  0.1402857 ,  0.03513321,  0.05450424,
#         0.09904657, -0.05291641,  0.1813988 , -0.01301383, -0.03586939,
#        -0.12604521, -0.07296988,  0.06289582,  0.00608337, -0.00747485,
#        -0.01584062,  0.04860228,  0.09789248,  0.08013952, -0.01947483,
#        -0.03901044,  0.02100712,  0.02659484, -0.04629436,  0.08243837,
#        -0.00642518, -0.07426196,  0.10372696, -0.00329005,  0.02359793,
#         0.04137665,  0.0867987 ,  0.01835357, -0.05258048, -0.04628946,
#        -0.01936685,  0.04456032, -0.0342486 , -0.02140936,  0.05341113,
#        -0.03789661,  0.04132101, -0.11633381, -0.18068919,  0.03370852,
#         0.0214502 ,  0.06464013,  0.01136789,  0.03267915,  0.0638374 ,
#         0.10388783,  0.01967398, -0.04917517,  0.05304422,  0.0757626 ,
#         0.02553906,  0.02246249,  0.02066038,  0.01855639, -0.10093669,
#        -0.01033617,  0.04647726, -0.00744433,  0.04917191,  0.03770955,
#         0.03700946,  0.05977885,  0.04923466,  0.04171079,  0.126396  ,
#        -0.01420179, -0.12135172,  0.02516398,  0.05740718,  0.15954979,
#        -0.12442041, -0.0080227 ,  0.08416388, -0.14752127, -0.04128838,
#        -0.06098286, -0.09691989, -0.04078628, -0.04911547, -0.06730995],
#       dtype=float32)

# %%
# Find the most similar words to "king" based on word vectors from our trained model
w2v_model.wv.most_similar('king')
# Out:
# [('haf', 0.9991196393966675),
#  ('or', 0.9991163611412048),
#  ('back', 0.9990954399108887),
#  ('told', 0.9990910291671753),
#  ('more', 0.9990885257720947),
#  ('call', 0.9990877509117126),
#  ('im', 0.9990752935409546),
#  ('half', 0.9990749359130859),
#  ('face', 0.9990745782852173),
#  ('work', 0.9990737438201904)]

# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index2word
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'in',
#  'is',
#  'me',
#  'it',
#  'my',
#  'for',
#  'your',
#  'of',
#  'call',
#  'that',
#  'have',
#  'on',
#  'are',
#  'so',
#  'now',
#  'can',
#  'but',
#  'we',
#  'not',
#  'or',
#  'get',
#  'do',
#  'will',
#  'at',
#  'if',
#  'ur',
#  'be',
#  'with',
#  'just',
#  'no',
#  'this',
#  'up',
#  'how',
#  'gt',
#  'when',
#  'ok',
#  'lt',
#  'go',
#  'from',
#  'what',
#  'free',
#  'all',
#  'out',
#  'll',
#  'know',
#  'got',
#  'good',
#  'then',
#  'like',
#  'day',
#  'was',
#  'its',
#  'am',
#  'he',
#  'there',
#  'come',
#  'time',
#  'only',
#  'send',
#  'love',
#  'want',
#  'text',
#  'one',
#  'as',
#  'txt',
#  'need',
#  'about',
#  'by',
#  'going',
#  'see',
#  'home',
#  'don',
#  'back',
#  'lor',
#  'today',
#  'stop',
#  'she',
#  'sorry',
#  'reply',
#  'da',
#  'our',
#  'hi',
#  'take',
#  'still',
#  'new',
#  'later',
#  'they',
#  'her',
#  'mobile',
#  'dont',
#  'pls',
#  'any',
#  'been',
#  'has',
#  'some',
#  'please',
#  'think',
#  'phone',
#  'an',
#  'tell',
#  'here',
#  'much',
#  'dear',
#  'ì_',
#  'msg',
#  'week',
#  'did',
#  'who',
#  'great',
#  'too',
#  'where',
#  'hope',
#  'well',
#  'night',
#  're',
#  'oh',
#  'him',
#  'more',
#  'happy',
#  'give',
#  'wat',
#  'claim',
#  'yes',
#  've',
#  'had',
#  'tomorrow',
#  'should',
#  'hey',
#  'make',
#  'www',
#  'number',
#  'message',
#  'won',
#  'way',
#  'say',
#  'ask',
#  'yeah',
#  'im',
#  'work',
#  'amp',
#  'already',
#  'prize',
#  'why',
#  'win',
#  'life',
#  'said',
#  'morning',
#  'cash',
#  'doing',
#  'right',
#  'really',
#  'after',
#  'meet',
#  'very',
#  'cos',
#  'let',
#  'them',
#  'find',
#  'com',
#  'anything',
#  'sure',
#  'babe',
#  'lol',
#  'miss',
#  'thanks',
#  'uk',
#  'buy',
#  'every',
#  'also',
#  'sent',
#  'last',
#  'care',
#  'would',
#  'pick',
#  'something',
#  'urgent',
#  'cant',
#  'min',
#  'first',
#  'nokia',
#  'nice',
#  'keep',
#  'thing',
#  'before',
#  'tonight',
#  'again',
#  'contact',
#  'off',
#  'over',
#  'many',
#  'which',
#  'his',
#  'someone',
#  'service',
#  'per',
#  'box',
#  'sms',
#  'wait',
#  'were',
#  'chat',
#  'money',
#  'us',
#  'feel',
#  'help',
#  'went',
#  'around',
#  'late',
#  'soon',
#  'wan',
#  'ya',
#  'next',
#  'mins',
#  'always',
#  'name',
#  'sleep',
#  'could',
#  'haha',
#  'leave',
#  'hello',
#  'place',
#  'pm',
#  'ìï',
#  'down',
#  'st',
#  'wish',
#  'friends',
#  'days',
#  'coming',
#  'gud',
#  'tone',
#  'gonna',
#  'co',
#  'heart',
#  'customer',
#  'dun',
#  'things',
#  'other',
#  'same',
#  'use',
#  'man',
#  'even',
#  'told',
#  'thk',
#  'live',
#  'smile',
#  'ppm',
#  'guaranteed',
#  'try',
#  'holiday',
#  'people',
#  'special',
#  'year',
#  'may',
#  'thought',
#  'best',
#  'person',
#  'th',
#  'waiting',
#  'class',
#  'never',
#  'yet',
#  'done',
#  'line',
#  'car',
#  'having',
#  'draw',
#  'ready',
#  'dat',
#  'few',
#  'getting',
#  'mind',
#  'better',
#  'bit',
#  'house',
#  'yo',
#  'didn',
#  'lar',
#  'wk',
#  'being',
#  'finish',
#  'god',
#  'fine',
#  'pobox',
#  'play',
#  'problem',
#  'cs',
#  'nothing',
#  'month',
#  'dinner',
#  'trying',
#  'stuff',
#  'ill',
#  'account',
#  'thats',
#  'friend',
#  'long',
#  'end',
#  'shit',
#  'big',
#  'talk',
#  'start',
#  'wanna',
#  'girl',
#  'eat',
#  'job',
#  'meeting',
#  'another',
#  'sweet',
#  'half',
#  'luv',
#  'sir',
#  'lot',
#  'lunch',
#  'receive',
#  'watching',
#  'shows',
#  'po',
#  'chance',
#  'yup',
#  'guess',
#  'because',
#  'cool',
#  'xxx',
#  'camera',
#  'awarded',
#  'part',
#  'birthday',
#  'landline',
#  'real',
#  'enjoy',
#  'ever',
#  'boy',
#  'tones',
#  'tv',
#  'quite',
#  'code',
#  'latest',
#  'hrs',
#  'might',
#  'liao',
#  'hour',
#  'guys',
#  'actually',
#  'two',
#  'princess',
#  'between',
#  'check',
#  'den',
#  'aight',
#  'pay',
#  'video',
#  'does',
#  'wont',
#  'into',
#  'jus',
#  'watch',
#  'forgot',
#  'bad',
#  'cost',
#  'world',
#  'than',
#  'probably',
#  'word',
#  'room',
#  'kiss',
#  'didnt',
#  'xx',
#  'put',
#  'baby',
#  'apply',
#  'speak',
#  'plan',
#  'bt',
#  'most',
#  'anyway',
#  'shall',
#  'fuck',
#  'bed',
#  'fun',
#  'working',
#  'bus',
#  'ringtone',
#  'shopping',
#  'nd',
#  'network',
#  'called',
#  'office',
#  'easy',
#  'remember',
#  'nite',
#  'missing',
#  'evening',
#  'hav',
#  'times',
#  'everything',
#  'look',
#  'early',
#  'details',
#  'face',
#  'thank',
#  'left',
#  'once',
#  'enough',
#  'offer',
#  'maybe',
#  'thanx',
#  'orange',
#  'valid',
#  'true',
#  'while',
#  'minutes',
#  'looking',
#  'rate',
#  'selected',
#  'award',
#  'means',
#  'reach',
#  'wake',
#  'okay',
#  'tmr',
#  'sat',
#  'weekend',
#  'little',
#  'wif',
#  'without',
#  'pain',
#  'alright',
#  'ah',
#  'ard',
#  'leh',
#  'haf',
#  'plus',
#  'dad',
#  'collect',
#  'until',
#  'wife',
#  'music',
#  'texts',
#  'asked',
#  'though',
#  'those',
#  'join',
#  'made',
#  'making',
#  'gift',
#  'age',
#  'important',
#  'sexy',
#  'oso',
#  'dis',
#  'til',
#  'dunno',
#  'collection',
#  'entry',
#  'says',
#  'wen',
#  'worry',
#  'since',
#  'plz',
#  'able',
#  'run',
#  'years',
#  'price',
#  'wanted',
#  'juz',
#  'driving',
#  'afternoon',
#  'hear',
#  'came',
#  'weekly',
#  'club',
#  'must',
#  'guy',
#  'wants',
#  'havent',
#  'show',
#  'makes',
#  'saw',
#  'goin',
#  'comes',
#  'decimal',
#  'games',
#  'else',
#  'bored',
#  'pa',
#  'xmas',
#  'shop',
#  'town',
#  'food',
#  'stay',
#  'messages',
#  'yesterday',
#  'abt',
#  'change',
#  'beautiful',
#  'pic',
#  'yourself',
#  'info',
#  'post',
#  'hot',
#  'yours',
#  'trip',
#  'walk',
#  'game',
#  'coz',
#  'double',
#  'mail',
#  'attempt',
#  'school',
#  'believe',
#  'net',
#  'full',
#  'words',
#  'movie',
#  'mob',
#  'saying',
#  'forget',
#  'simple',
#  'goes',
#  'took',
#  'lei',
#  'charge',
#  'hurt',
#  'bring',
#  'together',
#  'feeling',
#  'sch',
#  'dude',
#  'away',
#  'private',
#  'awesome',
#  'hair',
#  'old',
#  'id',
#  'everyone',
#  'missed',
#  'wid',
#  'email',
#  'address',
#  'unsubscribe',
#  'msgs',
#  'wot',
#  'both',
#  'leaving',
#  'top',
#  'news',
#  'lose',
#  'family',
#  'whats',
#  'ring',
#  'delivery',
#  'question',
#  'set',
#  'brother',
#  'head',
#  'noe',
#  'points',
#  'till',
#  'friendship',
#  'test',
#  'bonus',
#  'sae',
#  'date',
#  'de',
#  'tried',
#  'pics',
#  'update',
#  'whatever',
#  'angry',
#  'calls',
#  'thinking',
#  'final',
#  'expires',
#  'dreams',
#  'wil',
#  'order',
#  'auction',
#  'gr',
#  'online',
#  'answer',
#  'mean',
#  'poly',
#  'mine',
#  'close',
#  'available',
#  'suite',
#  'sleeping',
#  'statement',
#  'sister',
#  'lets',
#  'smiling',
#  'hours',
#  'await',
#  'taking',
#  'vouchers',
#  'http',
#  'rite',
#  'mum',
#  'dating',
#  'doesn',
#  'started',
#  'loving',
#  'story',
#  'eve',
#  'touch',
#  'smth',
#  'choose',
#  'huh',
#  'calling',
#  'busy',
#  'type',
#  'book',
#  'open',
#  'hl',
#  'break',
#  'gd',
#  'tomo',
#  'row',
#  'tot',
#  'aft',
#  'anyone',
#  'todays',
#  'haven',
#  'needs',
#  'identifier',
#  'either',
#  'sad',
#  'national',
#  'land',
#  'smoke',
#  'fri',
#  'carlos',
#  'nt',
#  'telling',
#  'bout',
#  'goodmorning',
#  'reason',
#  'lesson',
#  'colour',
#  'outside',
#  'content',
#  'ltd',
#  'congrats',
#  'kind',
#  'each',
#  'okie',
#  'drink',
#  'wonderful',
#  'takes',
#  'finished',
#  'drop',
#  'optout',
#  'drive',
#  'pounds',
#  'mom',
#  'dnt',
#  'happen',
#  'saturday',
#  'sunday',
#  'tel',
#  'christmas',
#  'decided',
#  'rs',
#  'second',
#  'these',
#  'card',
#  'sounds',
#  'jay',
#  'gbp',
#  'college',
#  'pub',
#  'snow',
#  'lands',
#  'case',
#  'û_',
#  'hit',
#  'earlier',
#  'least',
#  'wit',
#  'frnds',
#  'winner',
#  'frnd',
#  'alone',
#  'camcorder',
#  'search',
#  'press',
#  'neva',
#  'knw',
#  'light',
#  'lucky',
#  'their',
#  'mths',
#  'log',
#  'fast',
#  'company',
#  'treat',
#  'fancy',
#  'lovely',
#  'ni',
#  'download',
#  'cut',
#  'mayb',
#  'darren',
#  'oredi',
#  'information',
#  'uncle',
#  'correct',
#  'operator',
#  'sun',
#  'worth',
#  'understand',
#  'found',
#  'services',
#  'fone',
#  'weeks',
#  'mr',
#  'party',
#  'freemsg',
#  'fucking',
#  'read',
#  'un',
#  'darlin',
#  'friday',
#  'quiz',
#  'prob',
#  'bslvyl',
#  'anytime',
#  'far',
#  'tho',
#  'used',
#  'minute',
#  'mate',
#  'girls',
#  'hand',
#  'pretty',
#  'sis',
#  'hard',
#  'blue',
#  'phones',
#  'happened',
#  'listen',
#  'pass',
#  'hungry',
#  'yr',
#  'ass',
#  'nope',
#  'fr',
#  'opt',
#  'parents',
#  'almost',
#  'seeing',
#  'abiola',
#  'ha',
#  'chikku',
#  'lovable',
#  'support',
#  'crazy',
#  'talking',
#  'wkly',
#  'whole',
#  'offers',
#  'hows',
#  'visit',
#  'course',
#  'wrong',
#  'sending',
#  'couple',
#  'redeemed',
#  'march',
#  'father',
#  'laptop',
#  'rental',
#  'mu',
#  'rest',
#  'player',
#  'paper',
#  'die',
#  'hmv',
#  'eh',
#  'wow',
#  'gal',
#  'feels',
#  'reward',
#  'gettin',
#  'loads',
#  'gotta',
#  'voucher',
#  'gym',
#  'txts',
#  'extra',
#  'lots',
#  'welcome',
#  'sex',
#  'heard',
#  'wasn',
#  'hmmm',
#  'luck',
#  'hee',
#  'hmm',
#  'merry',
#  'seen',
#  'wishing',
#  'ipod',
#  'ex',
#  'ans',
#  'credit',
#  'computer',
#  'finally',
#  'asap',
#  'custcare',
#  'stupid',
#  'whenever',
#  'empty',
#  'police',
#  'picking',
#  'yar',
#  'park',
#  'surprise',
#  'happiness',
#  'savamob',
#  'supposed',
#  'mah',
#  'ten',
#  'secret',
#  'ago',
#  'gets',
#  'meant',
#  'checking',
#  'remove',
#  'john',
#  'direct',
#  'india',
#  'via',
#  'move',
#  'mobiles',
#  'project',
#  'wq',
#  'cum',
#  'sea',
#  'chennai',
#  'sk',
#  'reading',
#  'mobileupd',
#  'own',
#  'tc',
#  'callertune',
#  'gone',
#  'bcoz',
#  'congratulations',
#  'eg',
#  'etc',
#  'hold',
#  'gas',
#  'ugh',
#  'frm',
#  'area',
#  'slowly',
#  'boytoy',
#  'enter',
#  'difficult',
#  'warm',
#  'plans',
#  'met',
#  'shower',
#  'comin',
#  'questions',
#  'em',
#  'tickets',
#  'semester',
#  'point',
#  'comp',
#  'std',
#  'rates',
#  'monday',
#  'safe',
#  'red',
#  'save',
#  'within',
#  'bill',
#  'hg',
#  'hospital',
#  'catch',
#  'deep',
#  'lect',
#  'hiya',
#  'cause',
#  'mates',
#  'yrs',
#  'thinkin',
#  'thinks',
#  'wondering',
#  'bank',
#  'moment',
#  'side',
#  'felt',
#  'write',
#  'ac',
#  'lost',
#  'mrt',
#  'sony',
#  'none',
#  'caller',
#  'complimentary',
#  'wana',
#  'wc',
#  'confirm',
#  'terms',
#  'sitting',
#  'spend',
#  'worried',
#  'copy',
#  'otherwise',
#  'sort',
#  'months',
#  'valued',
#  'rply',
#  'pete',
#  'currently',
#  'blood',
#  'ntt',
#  'cr',
#  'figure',
#  'leaves',
#  'fantastic',
#  'somewhere',
#  'xy',
#  'sell',
#  'rd',
#  'pray',
#  'tired',
#  'energy',
#  'ts',
#  'seriously',
#  'itself',
#  'vl',
#  'entered',
#  'single',
#  'nobody',
#  'mo',
#  'rcvd',
#  'bathe',
#  'water',
#  'seems',
#  'paying',
#  'king',
#  'mrng',
#  'noon',
#  'dogging',
#  'nigeria',
#  'sound',
#  'during',
#  'muz',
#  'small',
#  'din',
#  'usual',
#  'possible',
#  'ive',
#  'men',
#  'bath',
#  'unless',
#  'wonder',
#  'doin',
#  'completely',
#  'rakhesh',
#  'england',
#  'ringtones',
#  'knew',
#  'training',
#  'match',
#  'normal',
#  'euro',
#  'cup',
#  'opinion',
#  'silent',
#  'na',
#  'black',
#  'slow',
#  'digital',
#  'film',
#  'glad',
#  'ar',
#  'la',
#  'tonite',
#  'children',
#  'meh',
#  'link',
#  'eyes',
#  'balance',
#  'numbers',
#  'wap',
#  'ish',
#  'deal',
#  'quick',
#  'bx',
#  'ip',
#  'bak',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index2word])
                     for ls in X_test])
# Out:
# C:\Users\archi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 1 1
# 152 144
# 5 5
# 5 4
# 23 19
# 6 5
# 11 10
# 25 25
# 8 7
# 16 12
# 13 13
# 28 23
# 2 2
# 13 12
# 6 6
# 4 4
# 8 6
# 21 19
# 23 21
# 10 10
# 13 12
# 12 12
# 8 7
# 17 16
# 29 29
# 10 10
# 20 20
# 5 5
# 20 15
# 5 5
# 18 18
# 21 18
# 17 13
# 15 15
# 5 5
# 8 7
# 30 28
# 14 13
# 14 12
# 12 12
# 26 25
# 18 17
# 23 19
# 33 25
# 34 30
# 12 12
# 22 22
# 5 3
# 31 29
# 14 12
# 20 19
# 1 1
# 13 13
# 3 3
# 14 14
# 16 15
# 7 6
# 12 12
# 12 10
# 23 23
# 9 9
# 8 8
# 12 10
# 5 5
# 11 11
# 21 21
# 7 7
# 22 22
# 9 5
# 11 11
# 27 27
# 22 20
# 17 14
# 23 22
# 7 5
# 4 4
# 7 6
# 6 6
# 32 32
# 19 19
# 4 4
# 9 9
# 24 24
# 9 5
# 8 8
# 5 5
# 10 10
# 14 11
# 4 4
# 10 8
# 21 21
# 22 19
# 9 9
# 11 11
# 6 6
# 22 18
# 7 6
# 21 21
# 11 10
# 10 8
# 24 17
# 10 10
# 4 3
# 3 3
# 9 8
# 6 6
# 15 13
# 7 2
# 31 31
# 8 7
# 12 12
# 28 18
# 5 4
# 7 5
# 2 2
# 16 13
# 24 21
# 10 10
# 8 8
# 5 2
# 8 7
# 15 14
# 29 28
# 14 12
# 21 14
# 19 19
# 11 11
# 24 22
# 2 2
# 67 66
# 8 6
# 26 26
# 11 11
# 1 1
# 15 12
# 28 25
# 7 7
# 4 4
# 16 16
# 27 27
# 3 2
# 11 11
# 5 5
# 4 3
# 4 2
# 9 7
# 16 14
# 5 5
# 17 17
# 30 28
# 23 21
# 17 17
# 6 6
# 31 31
# 1 1
# 10 9
# 41 34
# 24 23
# 10 10
# 19 15
# 6 5
# 13 12
# 23 22
# 21 19
# 3 3
# 19 19
# 14 13
# 6 5
# 13 12
# 12 11
# 2 2
# 15 13
# 28 25
# 6 6
# 9 9
# 12 11
# 10 6
# 18 17
# 101 101
# 9 1
# 21 20
# 31 31
# 15 13
# 19 16
# 23 20
# 26 26
# 13 13
# 30 29
# 8 7
# 1 1
# 2 2
# 13 12
# 15 14
# 4 4
# 26 24
# 4 4
# 7 7
# 4 4
# 11 11
# 8 8
# 7 6
# 13 11
# 13 11
# 5 5
# 8 8
# 19 16
# 4 2
# 8 8
# 30 30
# 5 5
# 8 7
# 20 20
# 15 14
# 5 3
# 10 8
# 5 4
# 27 27
# 25 20
# 6 6
# 7 7
# 14 13
# 5 5
# 7 6
# 8 8
# 8 8
# 24 24
# 30 26
# 2 2
# 10 9
# 9 9
# 6 6
# 13 10
# 20 20
# 18 17
# 8 7
# 13 12
# 13 11
# 26 24
# 17 13
# 11 9
# 17 13
# 17 16
# 8 7
# 8 8
# 6 6
# 27 26
# 4 4
# 16 16
# 29 28
# 22 22
# 5 5
# 24 17
# 7 7
# 10 10
# 7 6
# 20 20
# 12 12
# 19 16
# 8 8
# 19 15
# 19 17
# 6 6
# 13 13
# 2 2
# 29 28
# 28 28
# 36 33
# 29 27
# 5 5
# 6 6
# 4 4
# 7 7
# 5 5
# 22 19
# 5 5
# 25 22
# 17 17
# 17 15
# 21 21
# 1 1
# 4 4
# 3 3
# 21 20
# 8 7
# 29 28
# 5 4
# 4 4
# 4 4
# 8 7
# 8 8
# 7 5
# 6 4
# 7 6
# 33 26
# 14 9
# 13 13
# 6 6
# 9 8
# 21 21
# 9 8
# 18 18
# 3 3
# 33 27
# 17 17
# 3 3
# 7 5
# 6 6
# 24 23
# 21 21
# 6 5
# 23 22
# 5 5
# 6 5
# 12 12
# 7 5
# 5 5
# 8 6
# 5 4
# 8 8
# 5 3
# 26 24
# 16 16
# 5 5
# 9 8
# 4 2
# 5 5
# 4 4
# 21 17
# 8 7
# 9 9
# 6 5
# 14 13
# 7 6
# 1 1
# 7 5
# 25 24
# 11 9
# 6 6
# 2 2
# 22 15
# 9 8
# 16 16
# 10 8
# 26 21
# 13 13
# 2 2
# 26 24
# 5 5
# 21 21
# 12 12
# 11 10
# 17 15
# 17 17
# 21 21
# 29 29
# 8 8
# 22 20
# 9 9
# 7 6
# 9 9
# 9 9
# 19 14
# 4 2
# 14 13
# 20 20
# 14 13
# 26 26
# 4 4
# 8 8
# 15 15
# 4 2
# 5 5
# 15 15
# 29 29
# 8 7
# 30 29
# 29 24
# 11 11
# 6 5
# 6 5
# 6 6
# 17 17
# 7 7
# 11 8
# 16 16
# 8 8
# 9 8
# 7 5
# 8 8
# 7 7
# 19 19
# 6 3
# 5 5
# 9 9
# 17 15
# 22 21
# 23 22
# 8 8
# 6 6
# 10 9
# 10 10
# 9 9
# 17 17
# 8 7
# 4 3
# 26 22
# 9 8
# 8 8
# 9 9
# 5 4
# 6 5
# 11 11
# 8 8
# 12 12
# 26 25
# 6 5
# 5 5
# 5 5
# 27 25
# 14 13
# 5 5
# 7 7
# 11 10
# 6 6
# 26 24
# 11 10
# 25 25
# 15 14
# 23 21
# 9 9
# 7 7
# 11 11
# 5 4
# 4 4
# 20 20
# 5 5
# 11 10
# 5 5
# 56 55
# 18 16
# 14 11
# 7 6
# 27 26
# 8 8
# 23 22
# 8 8
# 27 24
# 7 5
# 7 6
# 12 10
# 5 4
# 4 4
# 13 13
# 5 4
# 8 7
# 26 24
# 15 14
# 1 1
# 27 23
# 10 8
# 8 8
# 4 2
# 61 59
# 12 11
# 18 17
# 23 23
# 5 4
# 9 9
# 2 2
# 6 5
# 11 10
# 9 9
# 11 9
# 13 12
# 4 4
# 17 13
# 30 28
# 5 4
# 9 6
# 8 8
# 12 12
# 5 5
# 14 14
# 16 16
# 7 5
# 7 7
# 19 16
# 7 5
# 8 8
# 5 5
# 5 5
# 17 17
# 16 16
# 16 14
# 6 6
# 5 5
# 8 7
# 24 24
# 10 10
# 6 5
# 29 29
# 26 24
# 17 16
# 15 13
# 23 18
# 16 15
# 15 15
# 12 11
# 2 0
# 3 3
# 6 6
# 20 18
# 13 12
# 27 27
# 7 7
# 21 18
# 17 16
# 4 4
# 28 25
# 17 17
# 22 20
# 4 4
# 20 15
# 25 21
# 9 9
# 9 7
# 3 1
# 8 7
# 6 6
# 9 8
# 5 4
# 14 14
# 46 43
# 12 12
# 110 81
# 18 17
# 14 11
# 5 5
# 12 12
# 19 13
# 11 10
# 7 5
# 14 14
# 22 22
# 13 10
# 11 9
# 6 5
# 26 24
# 9 9
# 49 43
# 13 13
# 5 5
# 10 10
# 4 4
# 18 16
# 12 9
# 11 11
# 13 13
# 25 24
# 24 21
# 25 25
# 27 27
# 6 6
# 19 13
# 32 31
# 23 23
# 21 21
# 4 4
# 22 20
# 16 14
# 27 24
# 25 20
# 22 18
# 4 4
# 20 20
# 11 10
# 7 7
# 11 8
# 18 17
# 6 6
# 4 4
# 4 4
# 51 43
# 6 6
# 26 20
# 16 11
# 7 7
# 13 11
# 16 14
# 22 21
# 23 23
# 3 2
# 29 28
# 6 5
# 26 20
# 10 10
# 11 10
# 14 14
# 10 8
# 19 19
# 8 8
# 11 10
# 11 11
# 11 9
# 8 7
# 7 7
# 17 15
# 6 4
# 6 4
# 24 22
# 17 16
# 11 11
# 27 22
# 5 5
# 18 15
# 7 6
# 7 7
# 4 4
# 14 14
# 8 8
# 9 8
# 20 18
# 5 5
# 22 21
# 18 16
# 8 8
# 13 13
# 12 12
# 36 34
# 11 10
# 5 5
# 23 21
# 6 3
# 7 6
# 6 6
# 4 4
# 23 23
# 17 13
# 16 11
# 7 4
# 22 20
# 10 10
# 2 2
# 14 14
# 13 13
# 7 7
# 4 1
# 29 26
# 7 7
# 18 18
# 8 8
# 6 6
# 5 5
# 12 10
# 5 5
# 12 12
# 8 7
# 11 9
# 5 5
# 17 16
# 3 2
# 30 30
# 23 20
# 12 10
# 9 8
# 8 4
# 7 7
# 11 9
# 35 31
# 8 5
# 20 18
# 12 10
# 13 10
# 24 24
# 9 9
# 10 10
# 4 4
# 8 7
# 15 15
# 25 25
# 7 7
# 4 4
# 26 26
# 30 30
# 8 6
# 23 23
# 22 22
# 9 9
# 17 8
# 11 10
# 15 13
# 12 11
# 6 5
# 12 12
# 12 11
# 4 4
# 17 14
# 9 9
# 10 9
# 4 4
# 7 4
# 19 19
# 13 12
# 6 4
# 9 9
# 4 4
# 29 24
# 11 9
# 13 11
# 17 15
# 14 14
# 29 29
# 7 7
# 22 19
# 26 23
# 9 8
# 6 5
# 6 6
# 6 6
# 11 10
# 13 13
# 4 4
# 21 20
# 9 9
# 10 9
# 21 20
# 5 5
# 9 9
# 3 3
# 7 6
# 9 8
# 14 11
# 14 14
# 12 11
# 5 3
# 6 5
# 22 21
# 8 7
# 42 39
# 11 10
# 23 20
# 8 7
# 5 2
# 5 5
# 8 7
# 22 22
# 10 10
# 7 7
# 24 23
# 4 4
# 6 6
# 10 10
# 7 7
# 8 8
# 5 5
# 5 5
# 14 13
# 30 25
# 29 25
# 16 11
# 33 30
# 16 16
# 10 10
# 34 32
# 14 14
# 27 26
# 5 5
# 21 20
# 22 21
# 27 23
# 37 32
# 28 28
# 5 5
# 11 10
# 10 9
# 6 6
# 10 9
# 7 7
# 4 4
# 3 3
# 19 19
# 6 6
# 12 10
# 13 12
# 10 9
# 4 3
# 12 12
# 2 2
# 21 18
# 10 10
# 19 19
# 14 12
# 16 12
# 21 20
# 10 7
# 25 23
# 8 7
# 8 8
# 4 4
# 5 3
# 6 6
# 20 20
# 9 7
# 15 14
# 12 11
# 24 24
# 47 40
# 28 25
# 10 10
# 16 14
# 30 29
# 6 6
# 0 0
# 8 8
# 5 4
# 10 9
# 6 6
# 13 13
# 24 22
# 6 6
# 13 13
# 7 7
# 20 20
# 5 4
# 8 8
# 8 7
# 9 9
# 9 6
# 10 10
# 6 6
# 23 17
# 25 25
# 5 3
# 7 7
# 4 4
# 3 3
# 6 4
# 21 21
# 7 5
# 19 16
# 8 8
# 27 25
# 4 4
# 23 22
# 4 4
# 9 9
# 9 9
# 5 5
# 18 16
# 10 9
# 83 63
# 21 20
# 22 20
# 16 15
# 11 11
# 8 8
# 11 10
# 8 6
# 24 20
# 5 5
# 8 8
# 23 21
# 7 7
# 5 5
# 14 14
# 7 6
# 8 7
# 23 22
# 21 19
# 23 21
# 5 5
# 1 1
# 12 9
# 7 6
# 17 16
# 14 13
# 10 7
# 12 11
# 3 3
# 4 4
# 4 4
# 3 1
# 6 6
# 9 6
# 17 14
# 18 18
# 9 8
# 21 21
# 19 17
# 31 29
# 30 29
# 16 16
# 9 8
# 6 6
# 8 8
# 8 2
# 9 9
# 6 5
# 14 13
# 23 23
# 12 9
# 23 23
# 8 7
# 10 10
# 26 25
# 8 8
# 6 6
# 30 30
# 5 5
# 4 4
# 15 12
# 29 28
# 4 4
# 11 11
# 27 27
# 16 15
# 10 7
# 6 3
# 24 23
# 6 6
# 9 9
# 11 9
# 20 20
# 15 14
# 27 25
# 28 27
# 4 4
# 18 16
# 11 11
# 7 7
# 20 17
# 1 1
# 22 22
# 27 20
# 6 6
# 3 3
# 14 14
# 7 6
# 27 26
# 6 5
# 10 10
# 14 13
# 22 17
# 7 7
# 6 4
# 16 16
# 5 5
# 29 27
# 9 9
# 6 6
# 12 10
# 4 3
# 19 16
# 10 10
# 5 5
# 16 13
# 62 55
# 9 9
# 10 10
# 6 6
# 7 6
# 10 8
# 5 4
# 17 16
# 30 25
# 23 17
# 22 19
# 6 5
# 8 8
# 15 14
# 22 20
# 11 10
# 5 5
# 11 11
# 10 8
# 8 8
# 25 25
# 11 6
# 4 4
# 8 2
# 8 8
# 9 6
# 9 8
# 24 21
# 6 5
# 14 13
# 7 5
# 29 29
# 8 8
# 16 12
# 7 7
# 6 5
# 21 20
# 7 6
# 29 29
# 51 46
# 30 28
# 7 5
# 10 10
# 5 3
# 55 44
# 6 5
# 23 23
# 8 8
# 14 14
# 25 23
# 29 26
# 31 29
# 8 8
# 23 22
# 18 17
# 34 33
# 8 6
# 8 8
# 20 17
# 26 25
# 23 23
# 5 5
# 8 7
# 19 13
# 19 19
# 18 16
# 26 23
# 9 7
# 26 23
# 5 4
# 24 22
# 17 15
# 13 11
# 5 5
# 5 5
# 8 8
# 29 28
# 8 2
# 4 4
# 22 22
# 25 20
# 10 10
# 5 5
# 6 5
# 10 7
# 17 8
# 24 20
# 31 29
# 9 8
# 18 16
# 10 10
# 5 5
# 25 19
# 6 5
# 28 26
# 22 21
# 5 3
# 0 0
# 4 3
# 17 16
# 16 15
# 17 17
# 5 5
# 5 4
# 8 5
# 15 10
# 15 14
# 9 9
# 29 29
# 22 21
# 23 19
# 24 21
# 5 5
# 6 6
# 12 10
# 6 6
# 9 8
# 26 24
# 19 19
# 8 6
# 8 8
# 25 20
# 4 4
# 17 11
# 6 6
# 7 7
# 5 4
# 17 16
# 9 9
# 29 28
# 23 23
# 31 26
# 9 8
# 13 13
# 20 20
# 17 14
# 13 11
# 28 26
# 12 12
# 22 21
# 8 5
# 16 16
# 8 7
# 30 30
# 17 16
# 7 6
# 28 21
# 9 8
# 22 17
# 28 27
# 8 8
# 6 6
# 2 2
# 15 13
# 19 17
# 18 17
# 9 9
# 15 14
# 13 12

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
# Are our sentence vector lengths consistent?
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 1 100
# 152 100
# 5 100
# 5 100
# 23 100
# 6 100
# 11 100
# 25 100
# 8 100
# 16 100
# 13 100
# 28 100
# 2 100
# 13 100
# 6 100
# 4 100
# 8 100
# 21 100
# 23 100
# 10 100
# 13 100
# 12 100
# 8 100
# 17 100
# 29 100
# 10 100
# 20 100
# 5 100
# 20 100
# 5 100
# 18 100
# 21 100
# 17 100
# 15 100
# 5 100
# 8 100
# 30 100
# 14 100
# 14 100
# 12 100
# 26 100
# 18 100
# 23 100
# 33 100
# 34 100
# 12 100
# 22 100
# 5 100
# 31 100
# 14 100
# 20 100
# 1 100
# 13 100
# 3 100
# 14 100
# 16 100
# 7 100
# 12 100
# 12 100
# 23 100
# 9 100
# 8 100
# 12 100
# 5 100
# 11 100
# 21 100
# 7 100
# 22 100
# 9 100
# 11 100
# 27 100
# 22 100
# 17 100
# 23 100
# 7 100
# 4 100
# 7 100
# 6 100
# 32 100
# 19 100
# 4 100
# 9 100
# 24 100
# 9 100
# 8 100
# 5 100
# 10 100
# 14 100
# 4 100
# 10 100
# 21 100
# 22 100
# 9 100
# 11 100
# 6 100
# 22 100
# 7 100
# 21 100
# 11 100
# 10 100
# 24 100
# 10 100
# 4 100
# 3 100
# 9 100
# 6 100
# 15 100
# 7 100
# 31 100
# 8 100
# 12 100
# 28 100
# 5 100
# 7 100
# 2 100
# 16 100
# 24 100
# 10 100
# 8 100
# 5 100
# 8 100
# 15 100
# 29 100
# 14 100
# 21 100
# 19 100
# 11 100
# 24 100
# 2 100
# 67 100
# 8 100
# 26 100
# 11 100
# 1 100
# 15 100
# 28 100
# 7 100
# 4 100
# 16 100
# 27 100
# 3 100
# 11 100
# 5 100
# 4 100
# 4 100
# 9 100
# 16 100
# 5 100
# 17 100
# 30 100
# 23 100
# 17 100
# 6 100
# 31 100
# 1 100
# 10 100
# 41 100
# 24 100
# 10 100
# 19 100
# 6 100
# 13 100
# 23 100
# 21 100
# 3 100
# 19 100
# 14 100
# 6 100
# 13 100
# 12 100
# 2 100
# 15 100
# 28 100
# 6 100
# 9 100
# 12 100
# 10 100
# 18 100
# 101 100
# 9 100
# 21 100
# 31 100
# 15 100
# 19 100
# 23 100
# 26 100
# 13 100
# 30 100
# 8 100
# 1 100
# 2 100
# 13 100
# 15 100
# 4 100
# 26 100
# 4 100
# 7 100
# 4 100
# 11 100
# 8 100
# 7 100
# 13 100
# 13 100
# 5 100
# 8 100
# 19 100
# 4 100
# 8 100
# 30 100
# 5 100
# 8 100
# 20 100
# 15 100
# 5 100
# 10 100
# 5 100
# 27 100
# 25 100
# 6 100
# 7 100
# 14 100
# 5 100
# 7 100
# 8 100
# 8 100
# 24 100
# 30 100
# 2 100
# 10 100
# 9 100
# 6 100
# 13 100
# 20 100
# 18 100
# 8 100
# 13 100
# 13 100
# 26 100
# 17 100
# 11 100
# 17 100
# 17 100
# 8 100
# 8 100
# 6 100
# 27 100
# 4 100
# 16 100
# 29 100
# 22 100
# 5 100
# 24 100
# 7 100
# 10 100
# 7 100
# 20 100
# 12 100
# 19 100
# 8 100
# 19 100
# 19 100
# 6 100
# 13 100
# 2 100
# 29 100
# 28 100
# 36 100
# 29 100
# 5 100
# 6 100
# 4 100
# 7 100
# 5 100
# 22 100
# 5 100
# 25 100
# 17 100
# 17 100
# 21 100
# 1 100
# 4 100
# 3 100
# 21 100
# 8 100
# 29 100
# 5 100
# 4 100
# 4 100
# 8 100
# 8 100
# 7 100
# 6 100
# 7 100
# 33 100
# 14 100
# 13 100
# 6 100
# 9 100
# 21 100
# 9 100
# 18 100
# 3 100
# 33 100
# 17 100
# 3 100
# 7 100
# 6 100
# 24 100
# 21 100
# 6 100
# 23 100
# 5 100
# 6 100
# 12 100
# 7 100
# 5 100
# 8 100
# 5 100
# 8 100
# 5 100
# 26 100
# 16 100
# 5 100
# 9 100
# 4 100
# 5 100
# 4 100
# 21 100
# 8 100
# 9 100
# 6 100
# 14 100
# 7 100
# 1 100
# 7 100
# 25 100
# 11 100
# 6 100
# 2 100
# 22 100
# 9 100
# 16 100
# 10 100
# 26 100
# 13 100
# 2 100
# 26 100
# 5 100
# 21 100
# 12 100
# 11 100
# 17 100
# 17 100
# 21 100
# 29 100
# 8 100
# 22 100
# 9 100
# 7 100
# 9 100
# 9 100
# 19 100
# 4 100
# 14 100
# 20 100
# 14 100
# 26 100
# 4 100
# 8 100
# 15 100
# 4 100
# 5 100
# 15 100
# 29 100
# 8 100
# 30 100
# 29 100
# 11 100
# 6 100
# 6 100
# 6 100
# 17 100
# 7 100
# 11 100
# 16 100
# 8 100
# 9 100
# 7 100
# 8 100
# 7 100
# 19 100
# 6 100
# 5 100
# 9 100
# 17 100
# 22 100
# 23 100
# 8 100
# 6 100
# 10 100
# 10 100
# 9 100
# 17 100
# 8 100
# 4 100
# 26 100
# 9 100
# 8 100
# 9 100
# 5 100
# 6 100
# 11 100
# 8 100
# 12 100
# 26 100
# 6 100
# 5 100
# 5 100
# 27 100
# 14 100
# 5 100
# 7 100
# 11 100
# 6 100
# 26 100
# 11 100
# 25 100
# 15 100
# 23 100
# 9 100
# 7 100
# 11 100
# 5 100
# 4 100
# 20 100
# 5 100
# 11 100
# 5 100
# 56 100
# 18 100
# 14 100
# 7 100
# 27 100
# 8 100
# 23 100
# 8 100
# 27 100
# 7 100
# 7 100
# 12 100
# 5 100
# 4 100
# 13 100
# 5 100
# 8 100
# 26 100
# 15 100
# 1 100
# 27 100
# 10 100
# 8 100
# 4 100
# 61 100
# 12 100
# 18 100
# 23 100
# 5 100
# 9 100
# 2 100
# 6 100
# 11 100
# 9 100
# 11 100
# 13 100
# 4 100
# 17 100
# 30 100
# 5 100
# 9 100
# 8 100
# 12 100
# 5 100
# 14 100
# 16 100
# 7 100
# 7 100
# 19 100
# 7 100
# 8 100
# 5 100
# 5 100
# 17 100
# 16 100
# 16 100
# 6 100
# 5 100
# 8 100
# 24 100
# 10 100
# 6 100
# 29 100
# 26 100
# 17 100
# 15 100
# 23 100
# 16 100
# 15 100
# 12 100
# 2 100
# 3 100
# 6 100
# 20 100
# 13 100
# 27 100
# 7 100
# 21 100
# 17 100
# 4 100
# 28 100
# 17 100
# 22 100
# 4 100
# 20 100
# 25 100
# 9 100
# 9 100
# 3 100
# 8 100
# 6 100
# 9 100
# 5 100
# 14 100
# 46 100
# 12 100
# 110 100
# 18 100
# 14 100
# 5 100
# 12 100
# 19 100
# 11 100
# 7 100
# 14 100
# 22 100
# 13 100
# 11 100
# 6 100
# 26 100
# 9 100
# 49 100
# 13 100
# 5 100
# 10 100
# 4 100
# 18 100
# 12 100
# 11 100
# 13 100
# 25 100
# 24 100
# 25 100
# 27 100
# 6 100
# 19 100
# 32 100
# 23 100
# 21 100
# 4 100
# 22 100
# 16 100
# 27 100
# 25 100
# 22 100
# 4 100
# 20 100
# 11 100
# 7 100
# 11 100
# 18 100
# 6 100
# 4 100
# 4 100
# 51 100
# 6 100
# 26 100
# 16 100
# 7 100
# 13 100
# 16 100
# 22 100
# 23 100
# 3 100
# 29 100
# 6 100
# 26 100
# 10 100
# 11 100
# 14 100
# 10 100
# 19 100
# 8 100
# 11 100
# 11 100
# 11 100
# 8 100
# 7 100
# 17 100
# 6 100
# 6 100
# 24 100
# 17 100
# 11 100
# 27 100
# 5 100
# 18 100
# 7 100
# 7 100
# 4 100
# 14 100
# 8 100
# 9 100
# 20 100
# 5 100
# 22 100
# 18 100
# 8 100
# 13 100
# 12 100
# 36 100
# 11 100
# 5 100
# 23 100
# 6 100
# 7 100
# 6 100
# 4 100
# 23 100
# 17 100
# 16 100
# 7 100
# 22 100
# 10 100
# 2 100
# 14 100
# 13 100
# 7 100
# 4 100
# 29 100
# 7 100
# 18 100
# 8 100
# 6 100
# 5 100
# 12 100
# 5 100
# 12 100
# 8 100
# 11 100
# 5 100
# 17 100
# 3 100
# 30 100
# 23 100
# 12 100
# 9 100
# 8 100
# 7 100
# 11 100
# 35 100
# 8 100
# 20 100
# 12 100
# 13 100
# 24 100
# 9 100
# 10 100
# 4 100
# 8 100
# 15 100
# 25 100
# 7 100
# 4 100
# 26 100
# 30 100
# 8 100
# 23 100
# 22 100
# 9 100
# 17 100
# 11 100
# 15 100
# 12 100
# 6 100
# 12 100
# 12 100
# 4 100
# 17 100
# 9 100
# 10 100
# 4 100
# 7 100
# 19 100
# 13 100
# 6 100
# 9 100
# 4 100
# 29 100
# 11 100
# 13 100
# 17 100
# 14 100
# 29 100
# 7 100
# 22 100
# 26 100
# 9 100
# 6 100
# 6 100
# 6 100
# 11 100
# 13 100
# 4 100
# 21 100
# 9 100
# 10 100
# 21 100
# 5 100
# 9 100
# 3 100
# 7 100
# 9 100
# 14 100
# 14 100
# 12 100
# 5 100
# 6 100
# 22 100
# 8 100
# 42 100
# 11 100
# 23 100
# 8 100
# 5 100
# 5 100
# 8 100
# 22 100
# 10 100
# 7 100
# 24 100
# 4 100
# 6 100
# 10 100
# 7 100
# 8 100
# 5 100
# 5 100
# 14 100
# 30 100
# 29 100
# 16 100
# 33 100
# 16 100
# 10 100
# 34 100
# 14 100
# 27 100
# 5 100
# 21 100
# 22 100
# 27 100
# 37 100
# 28 100
# 5 100
# 11 100
# 10 100
# 6 100
# 10 100
# 7 100
# 4 100
# 3 100
# 19 100
# 6 100
# 12 100
# 13 100
# 10 100
# 4 100
# 12 100
# 2 100
# 21 100
# 10 100
# 19 100
# 14 100
# 16 100
# 21 100
# 10 100
# 25 100
# 8 100
# 8 100
# 4 100
# 5 100
# 6 100
# 20 100
# 9 100
# 15 100
# 12 100
# 24 100
# 47 100
# 28 100
# 10 100
# 16 100
# 30 100
# 6 100
# 0 100
# 8 100
# 5 100
# 10 100
# 6 100
# 13 100
# 24 100
# 6 100
# 13 100
# 7 100
# 20 100
# 5 100
# 8 100
# 8 100
# 9 100
# 9 100
# 10 100
# 6 100
# 23 100
# 25 100
# 5 100
# 7 100
# 4 100
# 3 100
# 6 100
# 21 100
# 7 100
# 19 100
# 8 100
# 27 100
# 4 100
# 23 100
# 4 100
# 9 100
# 9 100
# 5 100
# 18 100
# 10 100
# 83 100
# 21 100
# 22 100
# 16 100
# 11 100
# 8 100
# 11 100
# 8 100
# 24 100
# 5 100
# 8 100
# 23 100
# 7 100
# 5 100
# 14 100
# 7 100
# 8 100
# 23 100
# 21 100
# 23 100
# 5 100
# 1 100
# 12 100
# 7 100
# 17 100
# 14 100
# 10 100
# 12 100
# 3 100
# 4 100
# 4 100
# 3 100
# 6 100
# 9 100
# 17 100
# 18 100
# 9 100
# 21 100
# 19 100
# 31 100
# 30 100
# 16 100
# 9 100
# 6 100
# 8 100
# 8 100
# 9 100
# 6 100
# 14 100
# 23 100
# 12 100
# 23 100
# 8 100
# 10 100
# 26 100
# 8 100
# 6 100
# 30 100
# 5 100
# 4 100
# 15 100
# 29 100
# 4 100
# 11 100
# 27 100
# 16 100
# 10 100
# 6 100
# 24 100
# 6 100
# 9 100
# 11 100
# 20 100
# 15 100
# 27 100
# 28 100
# 4 100
# 18 100
# 11 100
# 7 100
# 20 100
# 1 100
# 22 100
# 27 100
# 6 100
# 3 100
# 14 100
# 7 100
# 27 100
# 6 100
# 10 100
# 14 100
# 22 100
# 7 100
# 6 100
# 16 100
# 5 100
# 29 100
# 9 100
# 6 100
# 12 100
# 4 100
# 19 100
# 10 100
# 5 100
# 16 100
# 62 100
# 9 100
# 10 100
# 6 100
# 7 100
# 10 100
# 5 100
# 17 100
# 30 100
# 23 100
# 22 100
# 6 100
# 8 100
# 15 100
# 22 100
# 11 100
# 5 100
# 11 100
# 10 100
# 8 100
# 25 100
# 11 100
# 4 100
# 8 100
# 8 100
# 9 100
# 9 100
# 24 100
# 6 100
# 14 100
# 7 100
# 29 100
# 8 100
# 16 100
# 7 100
# 6 100
# 21 100
# 7 100
# 29 100
# 51 100
# 30 100
# 7 100
# 10 100
# 5 100
# 55 100
# 6 100
# 23 100
# 8 100
# 14 100
# 25 100
# 29 100
# 31 100
# 8 100
# 23 100
# 18 100
# 34 100
# 8 100
# 8 100
# 20 100
# 26 100
# 23 100
# 5 100
# 8 100
# 19 100
# 19 100
# 18 100
# 26 100
# 9 100
# 26 100
# 5 100
# 24 100
# 17 100
# 13 100
# 5 100
# 5 100
# 8 100
# 29 100
# 8 100
# 4 100
# 22 100
# 25 100
# 10 100
# 5 100
# 6 100
# 10 100
# 17 100
# 24 100
# 31 100
# 9 100
# 18 100
# 10 100
# 5 100
# 25 100
# 6 100
# 28 100
# 22 100
# 5 100
# 0 100
# 4 100
# 17 100
# 16 100
# 17 100
# 5 100
# 5 100
# 8 100
# 15 100
# 15 100
# 9 100
# 29 100
# 22 100
# 23 100
# 24 100
# 5 100
# 6 100
# 12 100
# 6 100
# 9 100
# 26 100
# 19 100
# 8 100
# 8 100
# 25 100
# 4 100
# 17 100
# 6 100
# 7 100
# 5 100
# 17 100
# 9 100
# 29 100
# 23 100
# 31 100
# 9 100
# 13 100
# 20 100
# 17 100
# 13 100
# 28 100
# 12 100
# 22 100
# 8 100
# 16 100
# 8 100
# 30 100
# 17 100
# 7 100
# 28 100
# 9 100
# 22 100
# 28 100
# 8 100
# 6 100
# 2 100
# 15 100
# 19 100
# 18 100
# 9 100
# 15 100
# 13 100
